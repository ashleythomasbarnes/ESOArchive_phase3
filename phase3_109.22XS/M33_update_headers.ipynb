# %%
from astropy.io import fits
import numpy as np
import re
from astropy.io.fits import Header

# %%
hdul_cube = fits.open("M33_cube.fits")
hdul_maps = fits.open("M33_MAPS.fits")
hdul_wl = fits.open("M33_whitelight.fits")

# %%
for hdul in [hdul_cube, hdul_maps, hdul_wl]:
    print(hdul.info())
# Out:
# Filename: M33_cube.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU     238   ()
#   1  DATA          1 ImageHDU        46   (20, 20, 3761)   float32
#   2  STAT          1 ImageHDU        47   (20, 20, 3761)   float32
#   3  DQ            1 ImageHDU        46   (20, 20, 3761)   uint8
# None
# Filename: M33_MAPS.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU     273   ()
#   1  ID            1 ImageHDU        25   (20, 20)   float64
#   2  FLUX          1 ImageHDU        26   (20, 20)   float64
#   3  SNR           1 ImageHDU        25   (20, 20)   float64
#   4  SNRBIN        1 ImageHDU        25   (20, 20)   float64
#   5  BIN_ID        1 ImageHDU        25   (20, 20)   float64
#   6  V_STARS       1 ImageHDU        26   (20, 20)   float64
#   7  FORM_ERR_V_STARS    1 ImageHDU        26   (20, 20)   float64
#   8  SIGMA_STARS    1 ImageHDU        26   (20, 20)   float64
#   9  FORM_ERR_SIGMA_STARS    1 ImageHDU        26   (20, 20)   float64
#  10  H3_STARS      1 ImageHDU        25   (20, 20)   float64
#  11  FORM_ERR_H3_STARS    1 ImageHDU        25   (20, 20)   float64
#  12  H4_STARS      1 ImageHDU        25   (20, 20)   float64
#  13  FORM_ERR_H4_STARS    1 ImageHDU        25   (20, 20)   float64
#  14  BIN_ID        1 ImageHDU        26   (20, 20)   float64
#  15  CHI2_TOT      1 ImageHDU        25   (20, 20)   float64
#  16  HB4861_FLUX    1 ImageHDU        26   (20, 20)   float64
#  17  HB4861_FLUX_ERR    1 ImageHDU        26   (20, 20)   float64
#  18  HB4861_VEL    1 ImageHDU        26   (20, 20)   float64
#  19  HB4861_VEL_ERR    1 ImageHDU        26   (20, 20)   float64
#  20  HB4861_SIGMA    1 ImageHDU        26   (20, 20)   float64
#  21  HB4861_SIGMA_ERR    1 ImageHDU        26   (20, 20)   float64
#  22  HB4861_SIGMA_CORR    1 ImageHDU        26   (20, 20)   float64
#  23  OIII4958_FLUX    1 ImageHDU        26   (20, 20)   float64
#  24  OIII4958_FLUX_ERR    1 ImageHDU        26   (20, 20)   float64
#  25  OIII4958_VEL    1 ImageHDU        26   (20, 20)   float64
#  26  OIII4958_VEL_ERR    1 ImageHDU        26   (20, 20)   float64
#  27  OIII4958_SIGMA    1 ImageHDU        26   (20, 20)   float64
#  28  OIII4958_SIGMA_ERR    1 ImageHDU        26   (20, 20)   float64
#  29  OIII4958_SIGMA_CORR    1 ImageHDU        26   (20, 20)   float64
#  30  OIII5006_FLUX    1 ImageHDU        26   (20, 20)   float64
#  31  OIII5006_FLUX_ERR    1 ImageHDU        26   (20, 20)   float64
#  32  OIII5006_VEL    1 ImageHDU        26   (20, 20)   float64
#  33  OIII5006_VEL_ERR    1 ImageHDU        26   (20, 20)   float64
#  34  OIII5006_SIGMA    1 ImageHDU        26   (20, 20)   float64
#  35  OIII5006_SIGMA_ERR    1 ImageHDU        26   (20, 20)   float64
#  36  OIII5006_SIGMA_CORR    1 ImageHDU        26   (20, 20)   float64
#  37  NI5197_FLUX    1 ImageHDU        26   (20, 20)   float64
#  38  NI5197_FLUX_ERR    1 ImageHDU        26   (20, 20)   float64
#  39  NI5197_VEL    1 ImageHDU        26   (20, 20)   float64
#  40  NI5197_VEL_ERR    1 ImageHDU        26   (20, 20)   float64
#  41  NI5197_SIGMA    1 ImageHDU        26   (20, 20)   float64
#  42  NI5197_SIGMA_ERR    1 ImageHDU        26   (20, 20)   float64
#  43  NI5197_SIGMA_CORR    1 ImageHDU        26   (20, 20)   float64
#  44  NI5200_FLUX    1 ImageHDU        26   (20, 20)   float64
#  45  NI5200_FLUX_ERR    1 ImageHDU        26   (20, 20)   float64
#  46  NI5200_VEL    1 ImageHDU        26   (20, 20)   float64
#  47  NI5200_VEL_ERR    1 ImageHDU        26   (20, 20)   float64
#  48  NI5200_SIGMA    1 ImageHDU        26   (20, 20)   float64
#  49  NI5200_SIGMA_ERR    1 ImageHDU        26   (20, 20)   float64
#  50  NI5200_SIGMA_CORR    1 ImageHDU        26   (20, 20)   float64
#  51  NII5754_FLUX    1 ImageHDU        26   (20, 20)   float64
#  52  NII5754_FLUX_ERR    1 ImageHDU        26   (20, 20)   float64
#  53  NII5754_VEL    1 ImageHDU        26   (20, 20)   float64
#  54  NII5754_VEL_ERR    1 ImageHDU        26   (20, 20)   float64
#  55  NII5754_SIGMA    1 ImageHDU        26   (20, 20)   float64
#  56  NII5754_SIGMA_ERR    1 ImageHDU        26   (20, 20)   float64
#  57  NII5754_SIGMA_CORR    1 ImageHDU        26   (20, 20)   float64
#  58  HEI5875_FLUX    1 ImageHDU        26   (20, 20)   float64
#  59  HEI5875_FLUX_ERR    1 ImageHDU        26   (20, 20)   float64
#  60  HEI5875_VEL    1 ImageHDU        26   (20, 20)   float64
#  61  HEI5875_VEL_ERR    1 ImageHDU        26   (20, 20)   float64
#  62  HEI5875_SIGMA    1 ImageHDU        26   (20, 20)   float64
#  63  HEI5875_SIGMA_ERR    1 ImageHDU        26   (20, 20)   float64
#  64  HEI5875_SIGMA_CORR    1 ImageHDU        26   (20, 20)   float64
#  65  OI6300_FLUX    1 ImageHDU        26   (20, 20)   float64
#  66  OI6300_FLUX_ERR    1 ImageHDU        26   (20, 20)   float64
#  67  OI6300_VEL    1 ImageHDU        26   (20, 20)   float64
#  68  OI6300_VEL_ERR    1 ImageHDU        26   (20, 20)   float64
#  69  OI6300_SIGMA    1 ImageHDU        26   (20, 20)   float64
#  70  OI6300_SIGMA_ERR    1 ImageHDU        26   (20, 20)   float64
#  71  OI6300_SIGMA_CORR    1 ImageHDU        26   (20, 20)   float64
#  72  SIII6312_FLUX    1 ImageHDU        26   (20, 20)   float64
#  73  SIII6312_FLUX_ERR    1 ImageHDU        26   (20, 20)   float64
#  74  SIII6312_VEL    1 ImageHDU        26   (20, 20)   float64
#  75  SIII6312_VEL_ERR    1 ImageHDU        26   (20, 20)   float64
#  76  SIII6312_SIGMA    1 ImageHDU        26   (20, 20)   float64
#  77  SIII6312_SIGMA_ERR    1 ImageHDU        26   (20, 20)   float64
#  78  SIII6312_SIGMA_CORR    1 ImageHDU        26   (20, 20)   float64
#  79  OI6363_FLUX    1 ImageHDU        26   (20, 20)   float64
#  80  OI6363_FLUX_ERR    1 ImageHDU        26   (20, 20)   float64
#  81  OI6363_VEL    1 ImageHDU        26   (20, 20)   float64
#  82  OI6363_VEL_ERR    1 ImageHDU        26   (20, 20)   float64
#  83  OI6363_SIGMA    1 ImageHDU        26   (20, 20)   float64
#  84  OI6363_SIGMA_ERR    1 ImageHDU        26   (20, 20)   float64
#  85  OI6363_SIGMA_CORR    1 ImageHDU        26   (20, 20)   float64
#  86  NII6548_FLUX    1 ImageHDU        26   (20, 20)   float64
#  87  NII6548_FLUX_ERR    1 ImageHDU        26   (20, 20)   float64
#  88  NII6548_VEL    1 ImageHDU        26   (20, 20)   float64
#  89  NII6548_VEL_ERR    1 ImageHDU        26   (20, 20)   float64
#  90  NII6548_SIGMA    1 ImageHDU        26   (20, 20)   float64
#  91  NII6548_SIGMA_ERR    1 ImageHDU        26   (20, 20)   float64
#  92  NII6548_SIGMA_CORR    1 ImageHDU        26   (20, 20)   float64
#  93  HA6562_FLUX    1 ImageHDU        26   (20, 20)   float64
#  94  HA6562_FLUX_ERR    1 ImageHDU        26   (20, 20)   float64
#  95  HA6562_VEL    1 ImageHDU        26   (20, 20)   float64
#  96  HA6562_VEL_ERR    1 ImageHDU        26   (20, 20)   float64
#  97  HA6562_SIGMA    1 ImageHDU        26   (20, 20)   float64
#  98  HA6562_SIGMA_ERR    1 ImageHDU        26   (20, 20)   float64
#  99  HA6562_SIGMA_CORR    1 ImageHDU        26   (20, 20)   float64
# 100  NII6583_FLUX    1 ImageHDU        26   (20, 20)   float64
# 101  NII6583_FLUX_ERR    1 ImageHDU        26   (20, 20)   float64
# 102  NII6583_VEL    1 ImageHDU        26   (20, 20)   float64
# 103  NII6583_VEL_ERR    1 ImageHDU        26   (20, 20)   float64
# 104  NII6583_SIGMA    1 ImageHDU        26   (20, 20)   float64
# 105  NII6583_SIGMA_ERR    1 ImageHDU        26   (20, 20)   float64
# 106  NII6583_SIGMA_CORR    1 ImageHDU        26   (20, 20)   float64
# 107  HEI6678_FLUX    1 ImageHDU        26   (20, 20)   float64
# 108  HEI6678_FLUX_ERR    1 ImageHDU        26   (20, 20)   float64
# 109  HEI6678_VEL    1 ImageHDU        26   (20, 20)   float64
# 110  HEI6678_VEL_ERR    1 ImageHDU        26   (20, 20)   float64
# 111  HEI6678_SIGMA    1 ImageHDU        26   (20, 20)   float64
# 112  HEI6678_SIGMA_ERR    1 ImageHDU        26   (20, 20)   float64
# 113  HEI6678_SIGMA_CORR    1 ImageHDU        26   (20, 20)   float64
# 114  SII6716_FLUX    1 ImageHDU        26   (20, 20)   float64
# 115  SII6716_FLUX_ERR    1 ImageHDU        26   (20, 20)   float64
# 116  SII6716_VEL    1 ImageHDU        26   (20, 20)   float64
# 117  SII6716_VEL_ERR    1 ImageHDU        26   (20, 20)   float64
# 118  SII6716_SIGMA    1 ImageHDU        26   (20, 20)   float64
# 119  SII6716_SIGMA_ERR    1 ImageHDU        26   (20, 20)   float64
# 120  SII6716_SIGMA_CORR    1 ImageHDU        26   (20, 20)   float64
# 121  SII6730_FLUX    1 ImageHDU        26   (20, 20)   float64
# 122  SII6730_FLUX_ERR    1 ImageHDU        26   (20, 20)   float64
# 123  SII6730_VEL    1 ImageHDU        26   (20, 20)   float64
# 124  SII6730_VEL_ERR    1 ImageHDU        26   (20, 20)   float64
# 125  SII6730_SIGMA    1 ImageHDU        26   (20, 20)   float64
# 126  SII6730_SIGMA_ERR    1 ImageHDU        26   (20, 20)   float64
# 127  SII6730_SIGMA_CORR    1 ImageHDU        26   (20, 20)   float64
# 128  HEI7065_FLUX    1 ImageHDU        26   (20, 20)   float64
# 129  HEI7065_FLUX_ERR    1 ImageHDU        26   (20, 20)   float64
# 130  HEI7065_VEL    1 ImageHDU        26   (20, 20)   float64
# 131  HEI7065_VEL_ERR    1 ImageHDU        26   (20, 20)   float64
# 132  HEI7065_SIGMA    1 ImageHDU        26   (20, 20)   float64
# 133  HEI7065_SIGMA_ERR    1 ImageHDU        26   (20, 20)   float64
# 134  HEI7065_SIGMA_CORR    1 ImageHDU        26   (20, 20)   float64
# 135  ARIII7135_FLUX    1 ImageHDU        26   (20, 20)   float64
# 136  ARIII7135_FLUX_ERR    1 ImageHDU        26   (20, 20)   float64
# 137  ARIII7135_VEL    1 ImageHDU        26   (20, 20)   float64
# 138  ARIII7135_VEL_ERR    1 ImageHDU        26   (20, 20)   float64
# 139  ARIII7135_SIGMA    1 ImageHDU        26   (20, 20)   float64
# 140  ARIII7135_SIGMA_ERR    1 ImageHDU        26   (20, 20)   float64
# 141  ARIII7135_SIGMA_CORR    1 ImageHDU        26   (20, 20)   float64
# 142  OII7318_FLUX    1 ImageHDU        26   (20, 20)   float64
# 143  OII7318_FLUX_ERR    1 ImageHDU        26   (20, 20)   float64
# 144  OII7318_VEL    1 ImageHDU        26   (20, 20)   float64
# 145  OII7318_VEL_ERR    1 ImageHDU        26   (20, 20)   float64
# 146  OII7318_SIGMA    1 ImageHDU        26   (20, 20)   float64
# 147  OII7318_SIGMA_ERR    1 ImageHDU        26   (20, 20)   float64
# 148  OII7318_SIGMA_CORR    1 ImageHDU        26   (20, 20)   float64
# 149  OII7319_FLUX    1 ImageHDU        26   (20, 20)   float64
# 150  OII7319_FLUX_ERR    1 ImageHDU        26   (20, 20)   float64
# 151  OII7319_VEL    1 ImageHDU        26   (20, 20)   float64
# 152  OII7319_VEL_ERR    1 ImageHDU        26   (20, 20)   float64
# 153  OII7319_SIGMA    1 ImageHDU        26   (20, 20)   float64
# 154  OII7319_SIGMA_ERR    1 ImageHDU        26   (20, 20)   float64
# 155  OII7319_SIGMA_CORR    1 ImageHDU        26   (20, 20)   float64
# 156  OII7329_FLUX    1 ImageHDU        26   (20, 20)   float64
# 157  OII7329_FLUX_ERR    1 ImageHDU        26   (20, 20)   float64
# 158  OII7329_VEL    1 ImageHDU        26   (20, 20)   float64
# 159  OII7329_VEL_ERR    1 ImageHDU        26   (20, 20)   float64
# 160  OII7329_SIGMA    1 ImageHDU        26   (20, 20)   float64
# 161  OII7329_SIGMA_ERR    1 ImageHDU        26   (20, 20)   float64
# 162  OII7329_SIGMA_CORR    1 ImageHDU        26   (20, 20)   float64
# 163  OII7330_FLUX    1 ImageHDU        26   (20, 20)   float64
# 164  OII7330_FLUX_ERR    1 ImageHDU        26   (20, 20)   float64
# 165  OII7330_VEL    1 ImageHDU        26   (20, 20)   float64
# 166  OII7330_VEL_ERR    1 ImageHDU        26   (20, 20)   float64
# 167  OII7330_SIGMA    1 ImageHDU        26   (20, 20)   float64
# 168  OII7330_SIGMA_ERR    1 ImageHDU        26   (20, 20)   float64
# 169  OII7330_SIGMA_CORR    1 ImageHDU        26   (20, 20)   float64
# 170  ARIV7332_FLUX    1 ImageHDU        26   (20, 20)   float64
# 171  ARIV7332_FLUX_ERR    1 ImageHDU        26   (20, 20)   float64
# 172  ARIV7332_VEL    1 ImageHDU        26   (20, 20)   float64
# 173  ARIV7332_VEL_ERR    1 ImageHDU        26   (20, 20)   float64
# 174  ARIV7332_SIGMA    1 ImageHDU        26   (20, 20)   float64
# 175  ARIV7332_SIGMA_ERR    1 ImageHDU        26   (20, 20)   float64
# 176  ARIV7332_SIGMA_CORR    1 ImageHDU        26   (20, 20)   float64
# 177  ARIII7751_FLUX    1 ImageHDU        26   (20, 20)   float64
# 178  ARIII7751_FLUX_ERR    1 ImageHDU        26   (20, 20)   float64
# 179  ARIII7751_VEL    1 ImageHDU        26   (20, 20)   float64
# 180  ARIII7751_VEL_ERR    1 ImageHDU        26   (20, 20)   float64
# 181  ARIII7751_SIGMA    1 ImageHDU        26   (20, 20)   float64
# 182  ARIII7751_SIGMA_ERR    1 ImageHDU        26   (20, 20)   float64
# 183  ARIII7751_SIGMA_CORR    1 ImageHDU        26   (20, 20)   float64
# 184  HPA118862_FLUX    1 ImageHDU        26   (20, 20)   float64
# 185  HPA118862_FLUX_ERR    1 ImageHDU        26   (20, 20)   float64
# 186  HPA118862_VEL    1 ImageHDU        26   (20, 20)   float64
# 187  HPA118862_VEL_ERR    1 ImageHDU        26   (20, 20)   float64
# 188  HPA118862_SIGMA    1 ImageHDU        26   (20, 20)   float64
# 189  HPA118862_SIGMA_ERR    1 ImageHDU        26   (20, 20)   float64
# 190  HPA118862_SIGMA_CORR    1 ImageHDU        26   (20, 20)   float64
# 191  HPA109015_FLUX    1 ImageHDU        26   (20, 20)   float64
# 192  HPA109015_FLUX_ERR    1 ImageHDU        26   (20, 20)   float64
# 193  HPA109015_VEL    1 ImageHDU        26   (20, 20)   float64
# 194  HPA109015_VEL_ERR    1 ImageHDU        26   (20, 20)   float64
# 195  HPA109015_SIGMA    1 ImageHDU        26   (20, 20)   float64
# 196  HPA109015_SIGMA_ERR    1 ImageHDU        26   (20, 20)   float64
# 197  HPA109015_SIGMA_CORR    1 ImageHDU        26   (20, 20)   float64
# 198  SIII9068_FLUX    1 ImageHDU        26   (20, 20)   float64
# 199  SIII9068_FLUX_ERR    1 ImageHDU        26   (20, 20)   float64
# 200  SIII9068_VEL    1 ImageHDU        26   (20, 20)   float64
# 201  SIII9068_VEL_ERR    1 ImageHDU        26   (20, 20)   float64
# 202  SIII9068_SIGMA    1 ImageHDU        26   (20, 20)   float64
# 203  SIII9068_SIGMA_ERR    1 ImageHDU        26   (20, 20)   float64
# 204  SIII9068_SIGMA_CORR    1 ImageHDU        26   (20, 20)   float64
# None
# Filename: M33_whitelight.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU     231   ()
#   1  DATA          1 ImageHDU        38   (20, 20)   float32
#   2  STAT          1 ImageHDU        38   (20, 20)   float32
# None

# %% [markdown]
# # Check and remove duplicates for OBID and PROV keywords in FITS headers

# %%
def dedupe_compact_prefix_keywords(
    header: Header,
    prefix: str = "OBID",
    normalize=lambda v: v.strip() if isinstance(v, str) else v,
):
    """
    De-duplicate and compact numbered FITS keywords with a common prefix.

    Example (prefix="OBID"):
      OBID1="A", OBID2="A", OBID3="B"  ->  OBID1="A", OBID2="B"
      OBID1="A", OBID3="A", OBID5="C"  ->  OBID1="A", OBID2="C"

    Rules:
      - Operates on keywords matching r'^{prefix}(\\d+)$'
      - Keeps the *first* occurrence of each value (after `normalize`)
      - Removes all duplicates
      - Renumbers sequentially starting at 1
      - Preserves the comment from the first kept occurrence of each value
      - Inserts the compacted block back at (approximately) the location of the
        first matching keyword in the original header.

    Parameters
    ----------
    header : astropy.io.fits.Header
        Header to modify in-place.
    prefix : str
        Keyword prefix, e.g. "OBID" or "PROV" (for "PROV1", "PROV2", ...).
    normalize : callable
        Function applied to values before comparing for duplicates.
        Default strips whitespace for strings.

    Returns
    -------
    header : Header
        The same header object (modified in-place).
    changed : bool
        True if any modifications were made.
    """
    pat = re.compile(rf"^{re.escape(prefix)}(\d+)$")

    # Collect matching cards (in header order), keeping original keyword and comment
    matches = []
    indices = []
    for idx, card in enumerate(header.cards):
        m = pat.match(card.keyword)
        if m:
            matches.append((card.keyword, card.value, card.comment))
            indices.append(idx)

    if not matches:
        return header, False

    # Determine reinsertion anchor: immediately after the card preceding the first match
    first_idx = min(indices)
    anchor_key = header.cards[first_idx - 1].keyword if first_idx > 0 else None

    # Build de-duplicated list (preserve first occurrence)
    seen = set()
    kept = []
    for key, val, com in matches:
        norm = normalize(val)
        if norm in seen:
            continue
        seen.add(norm)
        kept.append((val, com))

    # If already compact and unique with sequential numbering, we can still leave as-is,
    # but easiest is to rewrite deterministically.
    # Remove all matching keys first
    for key, _, _ in matches:
        if key in header:
            del header[key]

    # Insert back compacted keys with new numbering
    changed = True
    for i, (val, com) in enumerate(kept, start=1):
        newkey = f"{prefix}{i}"
        card_tuple = (newkey, val, com)

        if anchor_key is None:
            # insert at top, preserving order as a block
            header.insert(i - 1, card_tuple)
        else:
            # insert after anchor; update anchor so the block stays ordered
            header.insert(anchor_key, card_tuple, after=True)
            anchor_key = newkey

    return header, changed


def dedupe_compact_prefix_in_hdulist(hdulist, prefix: str = "OBID", **kwargs):
    """
    Apply `dedupe_compact_prefix_keywords` to every HDU header in an HDUList-like object.

    Returns a list of booleans indicating which HDUs were changed.
    """
    changed_flags = []
    for hdu in hdulist:
        _, changed = dedupe_compact_prefix_keywords(hdu.header, prefix=prefix, **kwargs)
        changed_flags.append(changed)
    return changed_flags

hdul_cube[0].header, changed = dedupe_compact_prefix_keywords(hdul_cube[0].header, prefix="OBID")
hdul_maps[0].header, changed = dedupe_compact_prefix_keywords(hdul_maps[0].header, prefix="OBID")
hdul_wl[0].header, changed = dedupe_compact_prefix_keywords(hdul_wl[0].header, prefix="OBID")

hdul_cube[0].header, changed = dedupe_compact_prefix_keywords(hdul_cube[0].header, prefix="PROV")
hdul_maps[0].header, changed = dedupe_compact_prefix_keywords(hdul_maps[0].header, prefix="PROV")
hdul_wl[0].header, changed = dedupe_compact_prefix_keywords(hdul_wl[0].header, prefix="PROV")

# %% [markdown]
# # Remove and replace keywords from all HDUs
#
# Updates:
# - Remove `COMMENT`
# - Update `PROCSOFT` -> "pymusepipe" (take from the paper)
# - Update `REFERENC` -> "doi:10.48550/arXiv.2509.15305"
# - `ABMAGLIM` -> **Need to get value from code provided**
# - `PIXNOISE` -> **Need to get value from code provided**
# - Update `BUNIT` -> following ESO convensions for cube and whitelight, and also maps (where needed)
# - Remove `PCi_j` in all HDUs (I think they were only present in the MAPS file?)
# - Update `WCSAXES` -> 2 (for whitelight image)
# - Update `RADESYS` -> "FK5" (in primary header of all files)
#
# This need updating after the cube and whitelight files have the same number of extensions:
# - Update `HDUDOC` -> "SPD" (for cube and whitelight headers - except primary)
# - Update `HDUVERS` -> "SDP Version 8" (for cube and whitelight headers - except primary)

# %%
for hdul in [hdul_cube, hdul_maps, hdul_wl]:
    for hdu in hdul:
        if "COMMENT" in hdu.header:
            del hdu.header["COMMENT"]

PROCSOFT = "pymusepipe"
REFERENC =  "doi:10.48550/arXiv.2509.15305"

ABMAGLIM = 10
PIXNOISE = 10

HDUDOC  = 'SDP'
HDUVERS = "SDP Version 8"

for hdul in [hdul_cube, hdul_maps, hdul_wl]:
    hdul[0].header["PROCSOFT"] = PROCSOFT
    hdul[0].header["REFERENC"] = REFERENC
    hdul[0].header["ABMAGLIM"] = ABMAGLIM
    hdul[0].header["PIXNOISE"] = PIXNOISE

# Remove PC1_1 and PC1_2 from all HDUs
for hdul in [hdul_cube, hdul_maps, hdul_wl]:
    for hdu in hdul:
        for PC in ["PC1_1", "PC1_2", "PC2_1", "PC2_2"]:
            if PC in hdu.header:
                del hdu.header[PC]

# This won't work as the number of HDUs differs bewteen the cube and the whitelight
for hdul in [hdul_cube, hdul_wl]:
    try:
        for hdu in [hdul[1], hdul[2], hdul[3]]:
            hdu.header["HDUDOC"] = HDUDOC
            hdu.header["HDUVERS"] = HDUVERS
    except IndexError:
        print("HDU index out of range, skipping...")
        pass

# Update format for units for cube and whitelight
for hdul in [hdul_cube, hdul_wl]:
    hdul[1].header["10**(-20)angstrom**(-1).cm**(-2).erg.s**(-1)"]
    hdul[2].header["10**(-40)angstrom**(-2).cm**(-4).erg**(2).s**(-2)"]

# Update format for unit format for maps
for hdu in hdul_maps[1:]:
    if "1e-20 erg/s/cm2/spaxel" in hdu.header.get("BUNIT", ""):
        hdu.header["BUNIT"] = "10**(-20)erg.s**(-1).cm**(-2).spaxel**(-1)"

# Set RADESYS to FK5 in primary headers
for hdul in [hdul_cube, hdul_maps, hdul_wl]:
    hdul[0].header["RADESYS"] = "FK5"
    hdul[0].header["EQUINOX"] = 2000.0

# Set WCSAXES to 2 in relevant HDUs
hdul_wl[1].header["WCSAXES"] = 2
hdul_wl[2].header["WCSAXES"] = 2
# Out:
# HDU index out of range, skipping...

# %%
## REMOVE -- ONLY FOR TESTING 
CRVAL1 = 23.462454565353
CRVAL2 = 30.624825604782

for hdul in [hdul_cube, hdul_maps, hdul_wl]:
    for hdu in hdul:
        if "RA" in hdu.header:
            hdu.header["RA"] = CRVAL1
        if "DEC" in hdu.header:
            hdu.header["DEC"] = CRVAL2
        if "CRPIX1" in hdu.header:
            hdu.header["CRPIX1"] = 1.0
        if "CRPIX2" in hdu.header:
            hdu.header["CRPIX2"] = 1.0

# %%
for hdul in [hdul_cube, hdul_maps, hdul_wl]:
    for hdu in hdul:
        hdu.add_datasum()
        hdu.add_checksum()

# Save to disk
hdul_cube.writeto("M33_cube_updated.fits", overwrite=True)
hdul_maps.writeto("M33_MAPS_updated.fits", overwrite=True)
hdul_wl.writeto("M33_whitelight_updated.fits", overwrite=True)
