# %%
from astropy.table import Table

# %%
dir_table = "./../tables/"
file_primary = f"{dir_table}table_primary.csv"
file_extension = f"{dir_table}table_extension.csv"

# %%
table_primary = Table.read(file_primary)
table_extension = Table.read(file_extension)

# %%
def get_values(product_name, table_primary, table_extension):

    print("------------------------------")
    print(f"{product_name} - Primary HDU")
    print("------------------------------")

    table_crop = table_primary['Column Name', product_name]
    for i in range(len(table_crop)):
        value = table_crop[table_crop.colnames[-1]][i]
        name = table_crop[table_crop.colnames[0]][i]
        if value != 'NA': 
            print(f"{name} {value}")

    print("------------------------------\n")

    print("------------------------------")
    print(f"{product_name} - Extension HDU")
    print("------------------------------")

    table_crop = table_extension['Column Name', product_name]
    for i in range(len(table_crop)):
        value = table_crop[table_crop.colnames[-1]][i]
        name = table_crop[table_crop.colnames[0]][i]
        if value != 'NA': 
            print(f"{name} {value}")

    print("------------------------------\n")

# get_values('IMAGE (single)', table_primary, table_extension)
get_values('IMAGE.FLUXMAP', table_primary, table_extension)
# get_values('SPECTRUM', table_primary, table_extension)
# Out:
# ------------------------------
# IMAGE.FLUXMAP - Primary HDU
# ------------------------------
# PRODCATG MM
# ASSOCi MA31
# ASSONi M33
# ASSOMi MA31
# ORIGIN MM
# TELESCOP TELESCi MM
# INSTRUME INSTRi MM
# FILTER FILTERi MM
# OBJECT MM
# RA DEC MM
# EQUINOX MA37
# RADESYS MM
# TIMESYS MA38
# EXPTIME MM
# TEXPTIME MM
# MJD-OBS MM
# MJD-END MM
# PROG_ID PROGIDi ME
# OBIDi ME
# NCOMBINE ME
# OBSTECH MM
# FLUXCAL MM
# PROCSOFT MM
# REFERENC M40
# PROVi PROVXTN ME
# BUNIT MM
# CRVALi MM
# CRPIXi MM
# CTYPEi MM
# CUNITi MM
# CDi_j MM
# CSYERi RC
# CRDERi RC
# FLUXERR MM
# WAVELMIN MM
# WAVELMAX MM
# RA_ERR NO
# DEC_ERR NO
# BNOISE MM
# MAPMODE MM
# FEBEi MM
# STOKES SU
# ABMAGLIM NO
# SKY_RES MM
# SKY_RERR MA50
# ARCFILE RE
# CHECKSUM MM
# DATASUM MM
# ORIGFILE RE
# P3ORIG RE
# NOESODAT MA59
# ------------------------------
#
# ------------------------------
# IMAGE.FLUXMAP - Extension HDU
# ------------------------------
# ARCFILE RE
# CHECKSUM MM
# DATASUM MM
# ORIGFILE RE
# P3ORIG RE
# EXTNAME MA65
# ------------------------------
